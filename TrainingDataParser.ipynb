# %%
import pandas as pd
from google.colab import files

uploaded = files.upload()

df_1 = pd.read_csv('df.csv')
df_2 = pd.read_csv('KOLList.csv')
# Out:
#      <input type="file" id="files-84e7d3c5-7e08-4553-b973-ca07bf1664e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-84e7d3c5-7e08-4553-b973-ca07bf1664e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_1['KOL'] = df_1['Author'].isin(df_2.loc[df_2['KOL'] == 1, 'Name']).astype(int)

print(df_1)

df_1.to_csv('train.csv', index=False)
files.download('train.csv')
# Out:
#              Author  Author ID  Publications  \
# 0          Wei Wang          1          2941
# 1           Wei Liu          2            20
# 2         Ying Wang          3           208
# 3         Xin Zhang          4           334
# 4          Yu Zhang          5           362
# ..              ...        ...           ...
# 837     Junmin Peng        995           297
# 838    Drew Pardoll        996           908
# 839  Brian Gonzalez        997           135
# 840      Andrew Wei        998           524
# 841      Chunyan Li        999            34
#
#                                           Affiliations  Citations  \
# 0    Department of Gastrointestinal, Bariatric and ...     173998
# 1    Department of Mammary Medicine, Affiliated Tum...     102782
# 2    Department of Cardiovascular Medicine, Mayo Cl...      24307
# 3    Department of Radiotherapy, Cancer Center, Sta...      22861
# 4    Institute of Spine and Spinal Cord, The First ...      58319
# ...
